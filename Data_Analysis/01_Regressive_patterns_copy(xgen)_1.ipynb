# %%
  # %pip install scalecast
  # %pip install statsmodels
# Out:
# Python interpreter will be restarted.
# Collecting scalecast
#   Downloading SCALECAST-0.18.16.tar.gz (901 kB)
# Requirement already satisfied: scikit-learn in /databricks/python3/lib/python3.9/site-packages (from scalecast) (1.0.2)
# Requirement already satisfied: statsmodels in /databricks/python3/lib/python3.9/site-packages (from scalecast) (0.13.2)
# Collecting tbats
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.9/site-packages (from scalecast) (1.7.3)
# Collecting eli5
#   Downloading eli5-0.13.0.tar.gz (216 kB)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.9/site-packages (from scalecast) (1.21.5)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (from scalecast) (1.4.2)
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.9/site-packages (from scalecast) (3.5.1)
# Requirement already satisfied: seaborn in /databricks/python3/lib/python3.9/site-packages (from scalecast) (0.11.2)
# Requirement already satisfied: xgboost in /databricks/python3/lib/python3.9/site-packages (from scalecast) (1.7.2)
# Requirement already satisfied: lightgbm>=3.2.1 in /databricks/python3/lib/python3.9/site-packages (from scalecast) (3.3.4)
# Collecting dask>=2023.3.2
#   Downloading dask-2023.8.1-py3-none-any.whl (1.2 MB)
# Collecting catboost
#   Downloading catboost-1.2-cp39-cp39-manylinux2014_x86_64.whl (98.6 MB)
# Requirement already satisfied: openpyxl in /databricks/python3/lib/python3.9/site-packages (from scalecast) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.9/site-packages (from dask>=2023.3.2->scalecast) (21.3)
# Collecting toolz>=0.10.0
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in /databricks/python3/lib/python3.9/site-packages (from dask>=2023.3.2->scalecast) (2022.2.0)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: click>=8.0 in /databricks/python3/lib/python3.9/site-packages (from dask>=2023.3.2->scalecast) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in /databricks/python3/lib/python3.9/site-packages (from dask>=2023.3.2->scalecast) (2.0.0)
# Collecting importlib-metadata>=4.13.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /databricks/python3/lib/python3.9/site-packages (from dask>=2023.3.2->scalecast) (6.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask>=2023.3.2->scalecast) (3.7.0)
# Requirement already satisfied: wheel in /databricks/python3/lib/python3.9/site-packages (from lightgbm>=3.2.1->scalecast) (0.37.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging>=20.0->dask>=2023.3.2->scalecast) (3.0.4)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->scalecast) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->scalecast) (1.1.1)
# Requirement already satisfied: plotly in /databricks/python3/lib/python3.9/site-packages (from catboost->scalecast) (5.6.0)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from catboost->scalecast) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas->scalecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas->scalecast) (2021.3)
# Requirement already satisfied: attrs>17.1.0 in /databricks/python3/lib/python3.9/site-packages (from eli5->scalecast) (21.4.0)
# Collecting jinja2>=3.0.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: tabulate>=0.7.7 in /databricks/python3/lib/python3.9/site-packages (from eli5->scalecast) (0.8.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.9/site-packages (from jinja2>=3.0.0->eli5->scalecast) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->scalecast) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->scalecast) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->scalecast) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->scalecast) (9.0.1)
# Requirement already satisfied: et-xmlfile in /databricks/python3/lib/python3.9/site-packages (from openpyxl->scalecast) (1.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from plotly->catboost->scalecast) (8.0.1)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.9/site-packages (from statsmodels->scalecast) (0.5.2)
# Requirement already satisfied: pmdarima in /databricks/python3/lib/python3.9/site-packages (from tbats->scalecast) (2.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /databricks/python3/lib/python3.9/site-packages (from pmdarima->tbats->scalecast) (61.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /databricks/python3/lib/python3.9/site-packages (from pmdarima->tbats->scalecast) (0.29.28)
# Requirement already satisfied: urllib3 in /databricks/python3/lib/python3.9/site-packages (from pmdarima->tbats->scalecast) (1.26.16)
# Building wheels for collected packages: scalecast, eli5
#   Building wheel for scalecast (setup.py): started
#   Building wheel for scalecast (setup.py): finished with status 'done'
#   Created wheel for scalecast: filename=SCALECAST-0.18.16-py3-none-any.whl size=116743 sha256=75a380633d805e669a77571e33f934a9302d8c6e75f18fccdd2fa4fdfbd987d6
#   Stored in directory: /root/.cache/pip/wheels/95/d1/8e/b378922916d920aa1912eb735f906e3087e0afec3ed33df4dd
#   Building wheel for eli5 (setup.py): started
#   Building wheel for eli5 (setup.py): finished with status 'done'
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107748 sha256=edbbdee757165927989a182e77960e771633851f6cd6e1833bbd2b6a6732b178
#   Stored in directory: /root/.cache/pip/wheels/7b/26/a5/8460416695a992a2966b41caa5338e5e7fcea98c9d032d055c
# Successfully built scalecast eli5
# Installing collected packages: toolz, locket, partd, jinja2, importlib-metadata, graphviz, tbats, eli5, dask, catboost, scalecast
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-86c46bb4-5321-4c64-9dff-e1af46936525
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Not uninstalling importlib-metadata at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-86c46bb4-5321-4c64-9dff-e1af46936525
#     Can't uninstall 'importlib-metadata'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.6.2 requires requests<2.29,>=2.24.0, but you have requests 2.31.0 which is incompatible.
# mlflow-skinny 2.1.1 requires importlib-metadata!=4.7.0,<6,>=3.7.0, but you have importlib-metadata 6.8.0 which is incompatible.
# Successfully installed catboost-1.2 dask-2023.8.1 eli5-0.13.0 graphviz-0.20.1 importlib-metadata-6.8.0 jinja2-3.1.2 locket-1.0.0 partd-1.4.0 scalecast-0.18.16 tbats-1.1.3 toolz-0.12.0
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Requirement already satisfied: statsmodels in /databricks/python3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: packaging>=21.3 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: pandas>=0.25 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: scipy>=1.3 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Python interpreter will be restarted.

# %%
# %run /Users/ebizindavyi@delhaize.be/Data_preparation/Parse_xls_files

# %%
from scalecast.Forecaster import Forecaster
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scalecast.auxmodels import auto_arima
from lightgbm import LGBMRegressor
import datetime as dt

# %% [markdown]
# ## Load the inbound data

# %%
inbound_2022_dir = '/dbfs/mnt/dataplatform/acc/DataScience/sandbox/ebiz/Inbound_FC/data/input/Ecom-Ops-status_2022.xlsx'

# %%
inbound_2022_df = create_master_df(inbound_2022_dir)

# %%
inbound_2022_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dates</th>
#       <th>Dry Fc</th>
#       <th>Dry Actuals</th>
#       <th>Fresh Fc</th>
#       <th>Fresh</th>
#       <th>Frozen Fc</th>
#       <th>Frozen</th>
#       <th>Ultrafresh Fc</th>
#       <th>Ultrafresh</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-03</td>
#       <td>85794.442754</td>
#       <td>84224.0</td>
#       <td>60969.286307</td>
#       <td>41000.0</td>
#       <td>49273.053738</td>
#       <td>5581.0</td>
#       <td>6538.217201</td>
#       <td>6538.217201</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-04</td>
#       <td>65323.939111</td>
#       <td>49564.0</td>
#       <td>68517.000793</td>
#       <td>64233.0</td>
#       <td>6447.045743</td>
#       <td>6110.0</td>
#       <td>7288.014352</td>
#       <td>9673.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-05</td>
#       <td>59060.496963</td>
#       <td>45890.0</td>
#       <td>59891.490569</td>
#       <td>61162.0</td>
#       <td>14752.884950</td>
#       <td>6061.0</td>
#       <td>8645.127518</td>
#       <td>9394.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2022-01-06</td>
#       <td>54098.434315</td>
#       <td>26976.0</td>
#       <td>54044.997867</td>
#       <td>55700.0</td>
#       <td>11884.161805</td>
#       <td>5042.0</td>
#       <td>8733.406013</td>
#       <td>7299.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2022-01-07</td>
#       <td>48633.525710</td>
#       <td>37044.0</td>
#       <td>48691.064872</td>
#       <td>49534.0</td>
#       <td>7322.811052</td>
#       <td>5979.0</td>
#       <td>7745.598367</td>
#       <td>8240.000000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>293</th>
#       <td>2022-12-27</td>
#       <td>71459.270000</td>
#       <td>63764.0</td>
#       <td>67049.998422</td>
#       <td>68912.0</td>
#       <td>6642.104962</td>
#       <td>5615.0</td>
#       <td>9028.927578</td>
#       <td>11033.000000</td>
#     </tr>
#     <tr>
#       <th>294</th>
#       <td>2022-12-28</td>
#       <td>71916.320000</td>
#       <td>47680.0</td>
#       <td>62406.358606</td>
#       <td>57239.0</td>
#       <td>5883.382433</td>
#       <td>5253.0</td>
#       <td>9509.601394</td>
#       <td>10525.000000</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>2022-12-29</td>
#       <td>60346.346000</td>
#       <td>39552.0</td>
#       <td>76619.568000</td>
#       <td>63748.0</td>
#       <td>5951.031775</td>
#       <td>6037.0</td>
#       <td>9399.318000</td>
#       <td>10458.000000</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td>2022-12-30</td>
#       <td>52203.888000</td>
#       <td>61119.0</td>
#       <td>65006.548000</td>
#       <td>42234.0</td>
#       <td>5759.074282</td>
#       <td>6692.0</td>
#       <td>9096.132000</td>
#       <td>7824.000000</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td>2022-12-31</td>
#       <td>62750.131426</td>
#       <td>46818.0</td>
#       <td>60982.180799</td>
#       <td>44876.0</td>
#       <td>5269.921775</td>
#       <td>4932.0</td>
#       <td>7219.766000</td>
#       <td>5975.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p>298 rows × 9 columns</p>
# </div>

# %% [markdown]
# ### Create yearly time series
# needed to fill in date gaps

# %%
calendar_2022 = pd.DataFrame({'Dates':pd.date_range(dt.datetime(2022,1,3), periods=363, freq='d')})
inbound_2022_dry = calendar_2022.merge(inbound_2022_df, on='Dates',how='left').fillna(0).set_index('Dates').copy()
inbound_2022_dry = inbound_2022_dry.groupby(['Dates'])['Dry Actuals'].sum()
inbound_2022_dry
# Out:
# Out[18]: Dates
# 2022-01-03    84224.0
# 2022-01-04    49564.0
# 2022-01-05    45890.0
# 2022-01-06    26976.0
# 2022-01-07    37044.0
#                ...
# 2022-12-27    63764.0
# 2022-12-28    47680.0
# 2022-12-29    39552.0
# 2022-12-30    61119.0
# 2022-12-31    46818.0
# Name: Dry Actuals, Length: 363, dtype: float64

# %% [markdown]
# ## Create forecasting element

# %%
new_f_element = Forecaster(
    y = inbound_2022_dry,
    current_dates = inbound_2022_dry.index,
    future_dates = 14,
    cis = False,
    metrics = ['rmse','mae','mape','r2']
)

# %%
# display the entire series
new_f_element.plot()
plt.show()

# %% [markdown]
# check any seasonal or cyclic patterns existing in the data

# %%
plt.rc("figure",figsize=(12,8))
new_f_element.seasonal_decompose().plot()
plt.show()

# %%
#mathematical proof
figs, axs = plt.subplots(2, 1,figsize=(9,9))
new_f_element.plot_acf(ax=axs[0],title='ACF',lags=15,color='black')
new_f_element.plot_pacf(ax=axs[1],title='PACF',lags=15,color='#B2C248',method='ywm')
plt.show()

# %% [markdown]
# ### Set the parameters
# Paremetize the forecast objects, the more features and parameters we set, the more we help the model to better performance

# %%
new_f_element.set_test_length(.20)

# %%
new_f_element.set_validation_length(5)

# %%
new_f_element.set_validation_metric('rmse')

# %%
new_f_element.eval_cis(
    mode = True,
    cilevel = .95,
)

# %%
new_f_element.add_seasonal_regressors(
'dayofweek',
'dayofyear',
'month',
'week',
'quarter',
raw=False,
sincos=True,
cycle_lens={'dayofyear':365.25},

)

# %%
new_f_element
# Out:
# Out[29]: Forecaster(
#     DateStartActuals=2022-01-03T00:00:00.000000000
#     DateEndActuals=2022-12-31T00:00:00.000000000
#     Freq=D
#     N_actuals=363
#     ForecastLength=14
#     Xvars=['dayofweeksin', 'dayofweekcos', 'dayofyearsin', 'dayofyearcos', 'monthsin', 'monthcos', 'weeksin', 'weekcos', 'quartersin', 'quartercos']
#     TestLength=72
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     CurrentEstimator=mlr
#     GridsFile=Grids
# )

# %%
#Add autoregressive term, consider 
new_f_element.add_ar_terms(14)

# %%
new_f_element
# Out:
# Out[31]: Forecaster(
#     DateStartActuals=2022-01-03T00:00:00.000000000
#     DateEndActuals=2022-12-31T00:00:00.000000000
#     Freq=D
#     N_actuals=363
#     ForecastLength=14
#     Xvars=['dayofweeksin', 'dayofweekcos', 'dayofyearsin', 'dayofyearcos', 'monthsin', 'monthcos', 'weeksin', 'weekcos', 'quartersin', 'quartercos', 'AR1', 'AR2', 'AR3', 'AR4', 'AR5', 'AR6', 'AR7', 'AR8', 'AR9', 'AR10', 'AR11', 'AR12', 'AR13', 'AR14']
#     TestLength=72
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     CurrentEstimator=mlr
#     GridsFile=Grids
# )

# %% [markdown]
# ### ARIMA model

# %%
# %%time
auto_arima(new_f_element,test='adf',seasonal=True,dynamic_testing=14,m=7,error_action="ignore")
# Out:
# CPU times: user 3min 29s, sys: 3min 47s, total: 7min 17s
# Wall time: 2min 39s

# %%
new_f_element.plot_test_set(models=['auto_arima'],ci=False,order_by='TestSetRMSE')
plt.show()

# %% [markdown]
# ## lightgbm model

# %%
# %%time
new_f_element.set_estimator('lightgbm')
new_f_element.manual_forecast(max_depth=2,dynamic_testing=14)
# Out:
# CPU times: user 9.03 s, sys: 1.94 s, total: 11 s
# Wall time: 10.6 s

# %%
new_f_element.plot_test_set(models=['lightgbm'],ci=False,order_by='TestSetRMSE')
plt.show()

# %%
# %%time
#max_depth= 3
new_f_element.set_estimator('lightgbm')
new_f_element.manual_forecast(call_me='lightgbm_2',max_depth=3,dynamic_testing=14)
# Out:
# CPU times: user 8.55 s, sys: 1.8 s, total: 10.3 s
# Wall time: 9.77 s

# %%
new_f_element.plot_test_set(models=['lightgbm_2'],ci=False)
plt.show()

# %%
# %%time
#max_depth= 4
new_f_element.set_estimator('lightgbm')
new_f_element.manual_forecast(call_me='lightgbm_3',max_depth=4,dynamic_testing=14)
# Out:
# CPU times: user 8.88 s, sys: 1.79 s, total: 10.7 s
# Wall time: 10.4 s

# %%
new_f_element.plot_test_set(models=['lightgbm_3'],ci=False)
plt.show()

# %% [markdown]
# ### KNN model

# %%
# %%time
# test the knn 
new_f_element.set_estimator('knn')
new_f_element.manual_forecast(n_neighbors=6,dynamic_testing=14)
# Out:
# CPU times: user 3.17 s, sys: 2.45 s, total: 5.62 s
# Wall time: 7.75 s

# %%
new_f_element.plot_test_set(models=['knn'],ci=False,order_by='TestSetRMSE')
# Out:
# Out[41]: <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
# %%time
# neighbor=4
neighbnew_f_element.set_estimator('knn')
new_f_element.manual_forecast(call_me='knn_2',n_neighbors=5,dynamic_testing=14)

# %%
new_f_element.plot_test_set(models=['knn_2'],ci=False,order_by='TestSetRMSE')
# Out:
# Out[43]: <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
# %%time
# n_neighbors=3
new_f_element.set_estimator('knn')
new_f_element.manual_forecast(call_me='knn_3',n_neighbors=3,dynamic_testing=14)
# Out:
# CPU times: user 3 s, sys: 2.53 s, total: 5.53 s
# Wall time: 7.73 s

# %%
new_f_element.plot_test_set(models=['knn_3'],ci=False,order_by='TestSetRMSE')
# Out:
# Out[45]: <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
# %%time
# n_neighbors=2
new_f_element.set_estimator('knn')
new_f_element.manual_forecast(call_me='knn_4',n_neighbors=2,dynamic_testing=14)
# Out:
# CPU times: user 2.9 s, sys: 2.45 s, total: 5.35 s
# Wall time: 7.86 s

# %%
new_f_element.plot_test_set(models=['knn_4'],ci=False,order_by='TestSetRMSE')
# Out:
# Out[47]: <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
new_f_element.plot_test_set(models=['auto_arima','knn','lightgbm'],ci=False,order_by='TestSetRMSE')
# Out:
# Out[48]: <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
new_f_element.export('model_summaries')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ModelNickname</th>
#       <th>Estimator</th>
#       <th>Xvars</th>
#       <th>HyperParams</th>
#       <th>Observations</th>
#       <th>DynamicallyTested</th>
#       <th>TestSetLength</th>
#       <th>CILevel</th>
#       <th>ValidationMetric</th>
#       <th>ValidationMetricValue</th>
#       <th>models</th>
#       <th>weights</th>
#       <th>best_model</th>
#       <th>InSampleRMSE</th>
#       <th>InSampleMAE</th>
#       <th>InSampleMAPE</th>
#       <th>InSampleR2</th>
#       <th>TestSetRMSE</th>
#       <th>TestSetMAE</th>
#       <th>TestSetMAPE</th>
#       <th>TestSetR2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>auto_arima</td>
#       <td>arima</td>
#       <td>[]</td>
#       <td>{'order': (1, 0, 0), 'seasonal_order': (2, 0, ...</td>
#       <td>363</td>
#       <td>1</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>True</td>
#       <td>20064.354289</td>
#       <td>12349.412478</td>
#       <td>NaN</td>
#       <td>0.616733</td>
#       <td>24819.066636</td>
#       <td>14450.584012</td>
#       <td>NaN</td>
#       <td>0.542018</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>lightgbm</td>
#       <td>lightgbm</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'max_depth': 2}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>14838.881293</td>
#       <td>9181.449908</td>
#       <td>NaN</td>
#       <td>0.793921</td>
#       <td>26731.928327</td>
#       <td>17738.501358</td>
#       <td>NaN</td>
#       <td>0.468702</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>lightgbm_2</td>
#       <td>lightgbm</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'max_depth': 3}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>11940.850725</td>
#       <td>7383.535559</td>
#       <td>NaN</td>
#       <td>0.866555</td>
#       <td>35102.776377</td>
#       <td>24890.481147</td>
#       <td>NaN</td>
#       <td>0.083862</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>lightgbm_3</td>
#       <td>lightgbm</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'max_depth': 4}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>9752.862815</td>
#       <td>6011.911747</td>
#       <td>NaN</td>
#       <td>0.910978</td>
#       <td>34759.082461</td>
#       <td>24482.865847</td>
#       <td>NaN</td>
#       <td>0.101714</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>knn</td>
#       <td>knn</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'n_neighbors': 6}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>18715.400657</td>
#       <td>10784.357938</td>
#       <td>NaN</td>
#       <td>0.672184</td>
#       <td>27182.156012</td>
#       <td>17301.387933</td>
#       <td>NaN</td>
#       <td>0.450654</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>knn_3</td>
#       <td>knn</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'n_neighbors': 3}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>15708.003084</td>
#       <td>8806.356817</td>
#       <td>NaN</td>
#       <td>0.769073</td>
#       <td>23903.818128</td>
#       <td>13288.312903</td>
#       <td>NaN</td>
#       <td>0.575173</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>knn_4</td>
#       <td>knn</td>
#       <td>[dayofweeksin, dayofweekcos, dayofyearsin, day...</td>
#       <td>{'n_neighbors': 2}</td>
#       <td>363</td>
#       <td>14</td>
#       <td>72</td>
#       <td>0.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>13872.347034</td>
#       <td>7675.659617</td>
#       <td>NaN</td>
#       <td>0.819892</td>
#       <td>24191.134538</td>
#       <td>13391.921953</td>
#       <td>NaN</td>
#       <td>0.564899</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### changing different parameters and add exogenous
# add more hyperparameter, such as, depth of trees in lightGBM, Number of K neighbours in Knn, lag for patterns

# %%
new_f_element.forecast('prophet')
new_f_element.manual_forecast()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-2454868232068326>:1
# ----> 1 new_f_element.forecast('prophet')
#       2 new_f_element.manual_forecast()
#
# TypeError: 'list' object is not callable
